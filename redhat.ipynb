# %%
import pandas as pd
import sys

# %%
import os

# %%
act_train_location = os.path.realpath('')+'/act_train.csv'

# %%
df_act_train = pd.read_csv(act_train_location)

# %%
df_act_train.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN    NaN
# 1   ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN    NaN
# 2   ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN    NaN
# 3   ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN    NaN
# 4   ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN    NaN
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 0    NaN    NaN    NaN    NaN    NaN    NaN  type 76        0
# 1    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 2    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 3    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 4    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0

# %%
people_location = os.path.realpath('')+'/people.csv'
df_people = pd.read_csv(people_location)

# %%
df_people.char_10.head()
# Out:
# 0     True
# 1    False
# 2     True
# 3     True
# 4    False
# Name: char_10, dtype: bool

# %%
df_people.head()
# Out:
#     people_id  char_1      group_1  char_2        date   char_3   char_4  \
# 0     ppl_100  type 2  group 17304  type 2  2021-06-29   type 5   type 5
# 1  ppl_100002  type 2   group 8688  type 3  2021-01-06  type 28   type 9
# 2  ppl_100003  type 2  group 33592  type 3  2022-06-10   type 4   type 8
# 3  ppl_100004  type 2  group 22593  type 3  2022-07-20  type 40  type 25
# 4  ppl_100006  type 2   group 6534  type 3  2022-07-27  type 40  type 25
#
#    char_5  char_6   char_7   ...   char_29 char_30 char_31 char_32 char_33  \
# 0  type 5  type 3  type 11   ...     False    True    True   False   False
# 1  type 5  type 3  type 11   ...     False    True    True    True    True
# 2  type 5  type 2   type 5   ...     False   False    True    True    True
# 3  type 9  type 4  type 16   ...      True    True    True    True    True
# 4  type 9  type 3   type 8   ...     False   False    True   False   False
#
#   char_34 char_35 char_36 char_37 char_38
# ...

# %%
df_people.dtypes
# Out:
# people_id    object
# char_1       object
# group_1      object
# char_2       object
# date         object
# char_3       object
# char_4       object
# char_5       object
# char_6       object
# char_7       object
# char_8       object
# char_9       object
# char_10        bool
# char_11        bool
# char_12        bool
# char_13        bool
# char_14        bool
# char_15        bool
# char_16        bool
# char_17        bool
# char_18        bool
# char_19        bool
# char_20        bool
# char_21        bool
# char_22        bool
# char_23        bool
# char_24        bool
# char_25        bool
# char_26        bool
# char_27        bool
# char_28        bool
# char_29        bool
# char_30        bool
# char_31        bool
# char_32        bool
# char_33        bool
# char_34        bool
# char_35        bool
# char_36        bool
# char_37        bool
# char_38       int64
# dtype: object

# %%
df_people.head()
# Out:
#     people_id  char_1      group_1  char_2        date   char_3   char_4  \
# 0     ppl_100  type 2  group 17304  type 2  2021-06-29   type 5   type 5
# 1  ppl_100002  type 2   group 8688  type 3  2021-01-06  type 28   type 9
# 2  ppl_100003  type 2  group 33592  type 3  2022-06-10   type 4   type 8
# 3  ppl_100004  type 2  group 22593  type 3  2022-07-20  type 40  type 25
# 4  ppl_100006  type 2   group 6534  type 3  2022-07-27  type 40  type 25
#
#    char_5  char_6   char_7   ...   char_29 char_30 char_31 char_32 char_33  \
# 0  type 5  type 3  type 11   ...     False    True    True   False   False
# 1  type 5  type 3  type 11   ...     False    True    True    True    True
# 2  type 5  type 2   type 5   ...     False   False    True    True    True
# 3  type 9  type 4  type 16   ...      True    True    True    True    True
# 4  type 9  type 3   type 8   ...     False   False    True   False   False
#
#   char_34 char_35 char_36 char_37 char_38
# ...

# %%
df_act_train.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN    NaN
# 1   ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN    NaN
# 2   ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN    NaN
# 3   ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN    NaN
# 4   ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN    NaN
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 0    NaN    NaN    NaN    NaN    NaN    NaN  type 76        0
# 1    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 2    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 3    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 4    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0

# %%
df_act_train.tail()
# Out:
#          people_id   activity_id        date activity_category char_1 char_2  \
# 2197286  ppl_99994  act2_4668076  2023-06-16            type 4    NaN    NaN
# 2197287  ppl_99994  act2_4743548  2023-03-30            type 4    NaN    NaN
# 2197288  ppl_99994   act2_536973  2023-01-19            type 2    NaN    NaN
# 2197289  ppl_99994   act2_688656  2023-05-02            type 4    NaN    NaN
# 2197290  ppl_99994   act2_715089  2023-06-15            type 2    NaN    NaN
#
#         char_3 char_4 char_5 char_6 char_7 char_8 char_9    char_10  outcome
# 2197286    NaN    NaN    NaN    NaN    NaN    NaN    NaN   type 418        1
# 2197287    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 1832        1
# 2197288    NaN    NaN    NaN    NaN    NaN    NaN    NaN     type 1        1
# 2197289    NaN    NaN    NaN    NaN    NaN    NaN    NaN   type 199        1
# 2197290    NaN    NaN    NaN    NaN    NaN    NaN    NaN     type 1        1

# %%
df_act_train.tail()
# Out:
#          people_id   activity_id        date activity_category char_1 char_2  \
# 2197286  ppl_99994  act2_4668076  2023-06-16            type 4    NaN    NaN
# 2197287  ppl_99994  act2_4743548  2023-03-30            type 4    NaN    NaN
# 2197288  ppl_99994   act2_536973  2023-01-19            type 2    NaN    NaN
# 2197289  ppl_99994   act2_688656  2023-05-02            type 4    NaN    NaN
# 2197290  ppl_99994   act2_715089  2023-06-15            type 2    NaN    NaN
#
#         char_3 char_4 char_5 char_6 char_7 char_8 char_9    char_10  outcome
# 2197286    NaN    NaN    NaN    NaN    NaN    NaN    NaN   type 418        1
# 2197287    NaN    NaN    NaN    NaN    NaN    NaN    NaN  type 1832        1
# 2197288    NaN    NaN    NaN    NaN    NaN    NaN    NaN     type 1        1
# 2197289    NaN    NaN    NaN    NaN    NaN    NaN    NaN   type 199        1
# 2197290    NaN    NaN    NaN    NaN    NaN    NaN    NaN     type 1        1

# %%
df_act_train.activity_category.unique()
# Out:
# array(['type 4', 'type 2', 'type 3', 'type 5', 'type 1', 'type 7', 'type 6'], dtype=object)

# %%
print df_act_train.char_10.unique()
# Out:
# ['type 76' 'type 1' 'type 1727' ..., 'type 7356' 'type 6865' 'type 7379']

# %%
df_people.char_10.unique()
# Out:
# array([True, False], dtype=object)

# %%
df_people.head()
# Out:
#     people_id  char_1      group_1  char_2        date   char_3   char_4  \
# 0     ppl_100  type 2  group 17304  type 2  2021-06-29   type 5   type 5
# 1  ppl_100002  type 2   group 8688  type 3  2021-01-06  type 28   type 9
# 2  ppl_100003  type 2  group 33592  type 3  2022-06-10   type 4   type 8
# 3  ppl_100004  type 2  group 22593  type 3  2022-07-20  type 40  type 25
# 4  ppl_100006  type 2   group 6534  type 3  2022-07-27  type 40  type 25
#
#    char_5  char_6   char_7   ...   char_29 char_30 char_31 char_32 char_33  \
# 0  type 5  type 3  type 11   ...     False    True    True   False   False
# 1  type 5  type 3  type 11   ...     False    True    True    True    True
# 2  type 5  type 2   type 5   ...     False   False    True    True    True
# 3  type 9  type 4  type 16   ...      True    True    True    True    True
# 4  type 9  type 3   type 8   ...     False   False    True   False   False
#
#   char_34 char_35 char_36 char_37 char_38
# ...

# %%
df_act_train.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN    NaN
# 1   ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN    NaN
# 2   ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN    NaN
# 3   ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN    NaN
# 4   ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN    NaN
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 0    NaN    NaN    NaN    NaN    NaN    NaN  type 76        0
# 1    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 2    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 3    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 4    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0

# %%
df_act_train.activity_category.unique()
# Out:
# array(['type 4', 'type 2', 'type 3', 'type 5', 'type 1', 'type 7', 'type 6'], dtype=object)

# %%
df_act_train.loc[df_act_train['activity_category']=='type 3',:]
# Out:
#           people_id   activity_id        date activity_category char_1 char_2  \
# 43       ppl_100006  act2_2380649  2022-07-27            type 3    NaN    NaN
# 50       ppl_100019  act2_1681678  2023-03-26            type 3    NaN    NaN
# 51       ppl_100019   act2_763203  2023-03-26            type 3    NaN    NaN
# 66       ppl_100025  act2_2597743  2022-08-26            type 3    NaN    NaN
# 99       ppl_100028  act2_2648774  2023-04-26            type 3    NaN    NaN
# 100      ppl_100028   act2_852379  2023-05-03            type 3    NaN    NaN
# 101      ppl_100029  act2_4406353  2023-07-15            type 3    NaN    NaN
# 102      ppl_100032  act2_1670126  2023-02-07            type 3    NaN    NaN
# 109      ppl_100033  act2_1085682  2023-06-15            type 3    NaN    NaN
# 110      ppl_100033  act2_1369916  2022-07-26            type 3    NaN    NaN
# 113      ppl_100033  act2_2859583  2023-02-28            type 3    NaN    NaN
# ...

# %%
newcolnames = []
for colname in df_act_train.columns:
    if 'char' in colname and 'a_a_a' in colname:
        newcolnames.append('a_'+colname[6:])
    elif 'date' in colname:
        newcolnames.append('a_'+colname)
    else:
        newcolnames.append(colname)
df_act_train.columns = newcolnames
newcolnames = []
for colname in df_people.columns:
    if 'char' in colname and 'p_p_p' in colname:
        newcolnames.append('p_'+colname[6:])
    elif 'date' in colname:
        newcolnames.append('p_'+colname)        
    else:
        newcolnames.append(colname)
df_people.columns = newcolnames

# %%
df_act_train = df_act_train.set_index('people_id')

# %%
df_people = df_people.set_index('people_id')

# %%
df = df_act_train.join(df_people)

# %%
df.head()
# Out:
#             activity_id      a_date activity_category a_char_1 a_char_2  \
# people_id
# ppl_100    act2_1734928  2023-08-26            type 4      NaN      NaN
# ppl_100    act2_2434093  2022-09-27            type 2      NaN      NaN
# ppl_100    act2_3404049  2022-09-27            type 2      NaN      NaN
# ppl_100    act2_3651215  2023-08-04            type 2      NaN      NaN
# ppl_100    act2_4109017  2023-08-26            type 2      NaN      NaN
#
#           a_char_3 a_char_4 a_char_5 a_char_6 a_char_7    ...    p_char_29  \
# people_id                                                 ...
# ppl_100        NaN      NaN      NaN      NaN      NaN    ...        False
# ppl_100        NaN      NaN      NaN      NaN      NaN    ...        False
# ppl_100        NaN      NaN      NaN      NaN      NaN    ...        False
# ppl_100        NaN      NaN      NaN      NaN      NaN    ...        False
# ppl_100        NaN      NaN      NaN      NaN      NaN    ...        False
#
# ...

# %%
df.columns
# Out:
# Index([u'activity_id', u'a_date', u'activity_category', u'a_char_1',
#        u'a_char_2', u'a_char_3', u'a_char_4', u'a_char_5', u'a_char_6',
#        u'a_char_7', u'a_char_8', u'a_char_9', u'a_char_10', u'outcome',
#        u'p_char_1', u'group_1', u'p_char_2', u'p_date', u'p_char_3',
#        u'p_char_4', u'p_char_5', u'p_char_6', u'p_char_7', u'p_char_8',
#        u'p_char_9', u'p_char_10', u'p_char_11', u'p_char_12', u'p_char_13',
#        u'p_char_14', u'p_char_15', u'p_char_16', u'p_char_17', u'p_char_18',
#        u'p_char_19', u'p_char_20', u'p_char_21', u'p_char_22', u'p_char_23',
#        u'p_char_24', u'p_char_25', u'p_char_26', u'p_char_27', u'p_char_28',
#        u'p_char_29', u'p_char_30', u'p_char_31', u'p_char_32', u'p_char_33',
#        u'p_char_34', u'p_char_35', u'p_char_36', u'p_char_37', u'p_char_38'],
#       dtype='object')

# %%
df_comp = df.fillna(value = 'type -1')

# %%
import pickle

# %%
df_comp.head()
# Out:
#             activity_id      a_date activity_category a_char_1 a_char_2  \
# people_id
# ppl_100    act2_1734928  2023-08-26            type 4  type -1  type -1
# ppl_100    act2_2434093  2022-09-27            type 2  type -1  type -1
# ppl_100    act2_3404049  2022-09-27            type 2  type -1  type -1
# ppl_100    act2_3651215  2023-08-04            type 2  type -1  type -1
# ppl_100    act2_4109017  2023-08-26            type 2  type -1  type -1
#
#           a_char_3 a_char_4 a_char_5 a_char_6 a_char_7    ...    p_char_29  \
# people_id                                                 ...
# ppl_100    type -1  type -1  type -1  type -1  type -1    ...        False
# ppl_100    type -1  type -1  type -1  type -1  type -1    ...        False
# ppl_100    type -1  type -1  type -1  type -1  type -1    ...        False
# ppl_100    type -1  type -1  type -1  type -1  type -1    ...        False
# ppl_100    type -1  type -1  type -1  type -1  type -1    ...        False
#
# ...

# %%
pickle.dump(df_comp,open('basic.pkl','wb'))

# %%
import pickle

# %%
df_comp = pickle.load(open('basic.pkl','rb'))

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df_comp.dtypes
# Out:
# activity_id          object
# a_date               object
# activity_category    object
# a_char_1             object
# a_char_2             object
# a_char_3             object
# a_char_4             object
# a_char_5             object
# a_char_6             object
# a_char_7             object
# a_char_8             object
# a_char_9             object
# a_char_10            object
# outcome               int64
# p_char_1             object
# group_1              object
# p_char_2             object
# p_date               object
# p_char_3             object
# p_char_4             object
# p_char_5             object
# p_char_6             object
# p_char_7             object
# p_char_8             object
# p_char_9             object
# p_char_10              bool
# p_char_11              bool
# p_char_12              bool
# p_char_13              bool
# p_char_14              bool
# p_char_15              bool
# p_char_16              bool
# p_char_17              bool
# ...

# %%
df_comp.p_char_1.head()
# Out:
# people_id
# ppl_100    type 2
# ppl_100    type 2
# ppl_100    type 2
# ppl_100    type 2
# ppl_100    type 2
# Name: p_char_1, dtype: object

# %%
Xtrain = df_comp.drop(['a_date','outcome','p_date','p_char_38'],axis=1).T.to_dict()
# Out:
# /home/rishik/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/pandas/core/frame.py:839: UserWarning: DataFrame columns are not unique, some columns will be omitted.
#   "columns will be omitted.", UserWarning)

# %%
from sklearn.feature_extraction import DictVectorizer

# %%
df_comp.head(30)
# Out:
#              activity_id      a_date activity_category a_char_1 a_char_2  \
# people_id
# ppl_100     act2_1734928  2023-08-26            type 4  type -1  type -1
# ppl_100     act2_2434093  2022-09-27            type 2  type -1  type -1
# ppl_100     act2_3404049  2022-09-27            type 2  type -1  type -1
# ppl_100     act2_3651215  2023-08-04            type 2  type -1  type -1
# ppl_100     act2_4109017  2023-08-26            type 2  type -1  type -1
# ppl_100      act2_898576  2023-08-04            type 4  type -1  type -1
# ppl_100002  act2_1233489  2022-11-23            type 2  type -1  type -1
# ppl_100002  act2_1623405  2022-11-23            type 2  type -1  type -1
# ppl_100003  act2_1111598  2023-02-07            type 2  type -1  type -1
# ppl_100003  act2_1177453  2023-06-28            type 2  type -1  type -1
# ppl_100003   act2_133509  2022-08-10            type 4  type -1  type -1
# ppl_100003  act2_1408475  2023-03-02            type 4  type -1  type -1
# ...

# %%
Xtrain
# Out:
# {'ppl_188810': {'a_char_1': 'type -1',
#   'a_char_10': 'type 1',
#   'a_char_2': 'type -1',
#   'a_char_3': 'type -1',
#   'a_char_4': 'type -1',
#   'a_char_5': 'type -1',
#   'a_char_6': 'type -1',
#   'a_char_7': 'type -1',
#   'a_char_8': 'type -1',
#   'a_char_9': 'type -1',
#   'activity_category': 'type 2',
#   'activity_id': 'act2_96164',
#   'group_1': 'group 2221',
#   'p_char_1': 'type 1',
#   'p_char_10': False,
#   'p_char_11': False,
#   'p_char_12': False,
#   'p_char_13': False,
#   'p_char_14': False,
#   'p_char_15': False,
#   'p_char_16': False,
#   'p_char_17': False,
#   'p_char_18': False,
#   'p_char_19': False,
#   'p_char_2': 'type 1',
#   'p_char_20': False,
#   'p_char_21': False,
#   'p_char_22': False,
#   'p_char_23': False,
#   'p_char_24': False,
#   'p_char_25': True,
#   'p_char_26': False,
#   'p_char_27': False,
#   'p_char_28': False,
#   'p_char_29': False,
#   'p_char_3': 'type 2',
#   'p_char_30': False,
#   'p_char_31': False,
# ...

# %%
dv = DictVectorizer()
dv.fit(Xtrain)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-32-0d3678d6c6ea> in <module>()
#       1 dv = DictVectorizer()
# ----> 2 dv.fit(Xtrain)
#
# /home/rishik/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/sklearn/feature_extraction/dict_vectorizer.py in fit(self, X, y)
#     114
#     115         for x in X:
# --> 116             for f, v in six.iteritems(x):
#     117                 if isinstance(v, six.string_types):
#     118                     f = "%s%s%s" % (f, self.separator, v)
#
# /home/rishik/Enthought/Canopy_64bit/User/lib/python2.7/site-packages/sklearn/externals/six.py in iteritems(d, **kw)
#     437 def iteritems(d, **kw):
#     438     """Return an iterator over the (key, value) pairs of a dictionary."""
# --> 439     return iter(getattr(d, _iteritems)(**kw))
#     440
#     441 def iterlists(d, **kw):
#
# ...
